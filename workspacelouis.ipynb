# %% [markdown]
# Belajar Visualisasi Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
filepath = "/drive/MyDrive/Colab Notebooks/CascadePeow/covid19.xlsx"

Data_Indo_Jak = pd.read_excel(filepath, sheet_name=0)
Data_Jak = pd.read_excel(filepath, sheet_name=1)
Data_Suspek_Jak = pd.read_excel(filepath, sheet_name=2)
Rdt_Ab = pd.read_excel(filepath, sheet_name=3)
Rdt_Ag = pd.read_excel(filepath, sheet_name=4)
Hasil_Lab = pd.read_excel(filepath, sheet_name=5)
Vak = pd.read_excel(filepath, sheet_name=6)
Pemakaman = pd.read_excel(filepath, sheet_name=7)
Vak_Wilayah = pd.read_excel(filepath, sheet_name=8)
Vak_Wilayah_Daily = pd.read_excel(filepath, sheet_name=9)

# %%
Data_Indo_Jak
# Out:
#        Tanggal  ...  Positif Aktif Harian (Jakarta)
# 0   2020-03-01  ...                               0
# 1   2020-03-02  ...                               0
# 2   2020-03-03  ...                               2
# 3   2020-03-04  ...                               0
# 4   2020-03-05  ...                               2
# ..         ...  ...                             ...
# 487 2021-07-01  ...                            3981
# 488 2021-07-02  ...                            4374
# 489 2021-07-03  ...                            3989
# 490 2021-07-04  ...                            4611
# 491 2021-07-05  ...                            4169
#
# [492 rows x 21 columns]

# %%
sns.set_style("whitegrid")
sns.lineplot(data=Data_Jak, x ="Tanggal", y="Meninggal")
sns.lineplot(data=Data_Jak, x ="Tanggal", y="Sembuh")
sns.lineplot(data=Data_Jak, x ="Tanggal", y="Masih Perawatan")
sns.lineplot(data=Data_Jak, x ="Tanggal", y="Self Isolation")

# %%
sns.lineplot(data=Data_Jak, x="Tanggal", y="Positif Harian")
koef = 10
Data_Jak_MA = Data_Jak["Positif Harian"].rolling(koef, min_periods=1).mean()
sns.lineplot(data=Data_Jak, x="Tanggal", y=Data_Jak_MA)

# %%
sns.lineplot(data=Data_Indo_Jak, x="Tanggal", y="Positif Harian (Indonesia)")
